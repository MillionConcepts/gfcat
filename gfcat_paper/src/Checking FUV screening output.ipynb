# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
from rich import print
from gfcat_utils import read_image, parse_exposure_time
from astropy.visualization import ZScaleInterval
from matplotlib.patches import Rectangle, Circle
from matplotlib.lines import Line2D
from matplotlib.text import Text
from lightcurve_interface_skeleton import screen_variables, load_lightcurve_records
from matplotlib.ticker import FormatStrFormatter, MaxNLocator

# %%
fn = '../data/e20214-fd-full.fits.gz'
imgmap, mask, edge, wcs, tranges, exptimes = read_image(fn)

# %%
plt.figure()
plt.imshow(ZScaleInterval()(imgmap),origin="lower", cmap="Greys_r");
plt.xticks([]);plt.yticks([]);
plt.figure()
plt.imshow(ZScaleInterval()(mask),origin="lower", cmap="Greys_r");
plt.xticks([]);plt.yticks([]);

# %%
plt.imshow(ZScaleInterval()(mask),origin="lower", cmap="Greys_r");
plt.xticks([]);plt.yticks([]);
